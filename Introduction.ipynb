# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity ="last_expr_or_assign"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gapminder-FiveYearData.csv")
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB
# None

# %%
country_df=df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
country_df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1704 entries, 0 to 1703
# Series name: country
# Non-Null Count  Dtype
# --------------  -----
# 1704 non-null   object
# dtypes: object(1)
# memory usage: 13.4+ KB

# %%
subset = df.loc[:,['year','pop']]
# Out:
#       year         pop
# 0     1952   8425333.0
# 1     1957   9240934.0
# 2     1962  10267083.0
# 3     1967  11537966.0
# 4     1972  13079460.0
# ...    ...         ...
# 1699  1987   9216418.0
# 1700  1992  10704340.0
# 1701  1997  11404948.0
# 1702  2002  11926563.0
# 1703  2007  12311143.0
#
# [1704 rows x 2 columns]

# %%
subset.head()
# Out:
#    year         pop
# 0  1952   8425333.0
# 1  1957   9240934.0
# 2  1962  10267083.0
# 3  1967  11537966.0
# 4  1972  13079460.0

# %% [markdown]
# #### This is the iloc allows to pick up the last column

# %%
subset2 = df.iloc[:,[2,4,-1]]
# Out:
#              pop  lifeExp   gdpPercap
# 0      8425333.0   28.801  779.445314
# 1      9240934.0   30.332  820.853030
# 2     10267083.0   31.997  853.100710
# 3     11537966.0   34.020  836.197138
# 4     13079460.0   36.088  739.981106
# ...          ...      ...         ...
# 1699   9216418.0   62.351  706.157306
# 1700  10704340.0   60.377  693.420786
# 1701  11404948.0   46.809  792.449960
# 1702  11926563.0   39.989  672.038623
# 1703  12311143.0   43.487  469.709298
#
# [1704 rows x 3 columns]

# %%
subset2
# Out:
#              pop  lifeExp   gdpPercap
# 0      8425333.0   28.801  779.445314
# 1      9240934.0   30.332  820.853030
# 2     10267083.0   31.997  853.100710
# 3     11537966.0   34.020  836.197138
# 4     13079460.0   36.088  739.981106
# ...          ...      ...         ...
# 1699   9216418.0   62.351  706.157306
# 1700  10704340.0   60.377  693.420786
# 1701  11404948.0   46.809  792.449960
# 1702  11926563.0   39.989  672.038623
# 1703  12311143.0   43.487  469.709298
#
# [1704 rows x 3 columns]

# %% [markdown]
# ### use range function to create a list of number sfrom 0 to 4

# %%
small_range= list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ##### use small_range to specify the column heads in the subset

# %%
subset3 = df.iloc[:,small_range]
# Out:
#           country  year         pop continent  lifeExp
# 0     Afghanistan  1952   8425333.0      Asia   28.801
# 1     Afghanistan  1957   9240934.0      Asia   30.332
# 2     Afghanistan  1962  10267083.0      Asia   31.997
# 3     Afghanistan  1967  11537966.0      Asia   34.020
# 4     Afghanistan  1972  13079460.0      Asia   36.088
# ...           ...   ...         ...       ...      ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487
#
# [1704 rows x 5 columns]

# %%
subset3
# Out:
#           country  year         pop continent  lifeExp
# 0     Afghanistan  1952   8425333.0      Asia   28.801
# 1     Afghanistan  1957   9240934.0      Asia   30.332
# 2     Afghanistan  1962  10267083.0      Asia   31.997
# 3     Afghanistan  1967  11537966.0      Asia   34.020
# 4     Afghanistan  1972  13079460.0      Asia   36.088
# ...           ...   ...         ...       ...      ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487
#
# [1704 rows x 5 columns]

# %%
subset3.tail
# Out:
# <bound method NDFrame.tail of           country  year         pop continent  lifeExp
# 0     Afghanistan  1952   8425333.0      Asia   28.801
# 1     Afghanistan  1957   9240934.0      Asia   30.332
# 2     Afghanistan  1962  10267083.0      Asia   31.997
# 3     Afghanistan  1967  11537966.0      Asia   34.020
# 4     Afghanistan  1972  13079460.0      Asia   36.088
# ...           ...   ...         ...       ...      ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487
#
# [1704 rows x 5 columns]>

# %% [markdown]
# #### Using loc for accessing a cell by providing  row no and column name

# %%
df.loc[42,'country']
# Out:
# 'Angola'

# %% [markdown]
# #### Using iloc command access a cell by providing row and column no

# %%
df.iloc[42,0]
# Out:
# 'Angola'

# %% [markdown]
# #### Acess a particular rows and for selected comluns using iloc

# %%
df.iloc[[3,8,999,-1],[2,5,-1]]
# Out:
#              pop    gdpPercap    gdpPercap
# 3     11537966.0   836.197138   836.197138
# 8     16317921.0   649.341395   649.341395
# 999    1149500.0  1226.041130  1226.041130
# 1703  12311143.0   469.709298   469.709298

# %% [markdown]
# #### Using column names instead of numbers to make code more readable

# %%
df.loc[[3,328,99,],['year','country','pop']]
# Out:
#      year          country         pop
# 3    1967      Afghanistan  11537966.0
# 328  1972  Congo Dem. Rep.  23007669.0
# 99   1967       Bangladesh  62821884.0

# %% [markdown]
# ### use loc, : and [cloumn_name] for set of rows

# %%
df.loc[23:37,['country','year','pop']]
# Out:
#     country  year         pop
# 23  Albania  2007   3600523.0
# 24  Algeria  1952   9279525.0
# 25  Algeria  1957  10270856.0
# 26  Algeria  1962  11000948.0
# 27  Algeria  1967  12760499.0
# 28  Algeria  1972  14760787.0
# 29  Algeria  1977  17152804.0
# 30  Algeria  1982  20033753.0
# 31  Algeria  1987  23254956.0
# 32  Algeria  1992  26298373.0
# 33  Algeria  1997  29072015.0
# 34  Algeria  2002  31287142.0
# 35  Algeria  2007  33333216.0
# 36   Angola  1952   4232095.0
# 37   Angola  1957   4561361.0

# %% [markdown]
# #### groupby and mean

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %% [markdown]
# #### Multiple columns are stacked

# %%
multi_group_var = df.groupby(['year','continent'])[['lifeExp','gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %% [markdown]
# #### flatten the data --- stacked table to flat

# %%
flat= multi_group_var.reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %% [markdown]
# #### get unique values using nunique

# %%
x= df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
x= df.groupby('continent')['country'].nunique()
type(x)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### use python inbuilt method "dir" to see the  methods and atrributes associated with x which is panda.core.series.Series type of object

# %%
dir(x)
# Out:
# ['Africa',
#  'Americas',
#  'Asia',
#  'Europe',
#  'Oceania',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
# ...

# %% [markdown]
# ### Basic Plot

# %% [markdown]
# #### Find year wise life expentence using groupby  and mean method

# %%
globaly_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
globaly_yearly_life_expectancy.plot()
# Out:
# <AxesSubplot: xlabel='year'>
